# %% [markdown]
# <a href="https://colab.research.google.com/github/NSasiV/github-slideshow/blob/master/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PANDAS
#
#
#
#
#         https://www.youtube.com/watch?v=vmEHCJofslg&t=4s
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/pokemon.csv')

# %%
print(df)
# Out:
#                        abilities  against_bug  ...  generation  is_legendary
# 0    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 1    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 2    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 3       ['Blaze', 'Solar Power']         0.50  ...           1             0
# 4       ['Blaze', 'Solar Power']         0.50  ...           1             0
# ..                           ...          ...  ...         ...           ...
# 796              ['Beast Boost']         0.25  ...           7             1
# 797              ['Beast Boost']         1.00  ...           7             1
# 798              ['Beast Boost']         2.00  ...           7             1
# 799              ['Prism Armor']         2.00  ...           7             1
# 800               ['Soul-Heart']         0.25  ...           7             1
#
# [801 rows x 41 columns]

# %%
df.head(3)
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
#
# [3 rows x 41 columns]

# %%
df.tail(3)
# Out:
#            abilities  against_bug  ...  generation  is_legendary
# 798  ['Beast Boost']         2.00  ...           7             1
# 799  ['Prism Armor']         2.00  ...           7             1
# 800   ['Soul-Heart']         0.25  ...           7             1
#
# [3 rows x 41 columns]

# %%
# Read Headers
print(df.columns)
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
print(df['name'][0:5]) #df.name also give same ans
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: name, dtype: object

# %%
print(df[['name','type1']])
# Out:
#            name    type1
# 0     Bulbasaur    grass
# 1       Ivysaur    grass
# 2      Venusaur    grass
# 3    Charmander     fire
# 4    Charmeleon     fire
# ..          ...      ...
# 796  Celesteela    steel
# 797     Kartana    grass
# 798    Guzzlord     dark
# 799    Necrozma  psychic
# 800    Magearna    steel
#
# [801 rows x 2 columns]

# %%
df.iloc[0:4]
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [4 rows x 41 columns]

# %%
df.iloc[2,1] #row, col
# Out:
# 1.0

# %%
# to iterate throug rows
for index, row in df.iterrows():
    print(index,row['name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 Charmander
# 4 Charmeleon
# 5 Charizard
# 6 Squirtle
# 7 Wartortle
# 8 Blastoise
# 9 Caterpie
# 10 Metapod
# 11 Butterfree
# 12 Weedle
# 13 Kakuna
# 14 Beedrill
# 15 Pidgey
# 16 Pidgeotto
# 17 Pidgeot
# 18 Rattata
# 19 Raticate
# 20 Spearow
# 21 Fearow
# 22 Ekans
# 23 Arbok
# 24 Pikachu
# 25 Raichu
# 26 Sandshrew
# 27 Sandslash
# 28 Nidoran♀
# 29 Nidorina
# 30 Nidoqueen
# 31 Nidoran♂
# 32 Nidorino
# 33 Nidoking
# 34 Clefairy
# 35 Clefable
# 36 Vulpix
# 37 Ninetales
# 38 Jigglypuff
# 39 Wigglytuff
# 40 Zubat
# 41 Golbat
# 42 Oddish
# 43 Gloom
# 44 Vileplume
# 45 Paras
# 46 Parasect
# 47 Venonat
# 48 Venomoth
# 49 Diglett
# 50 Dugtrio
# 51 Meowth
# 52 Persian
# 53 Psyduck
# 54 Golduck
# 55 Mankey
# 56 Primeape
# 57 Growlithe
# 58 Arcanine
# 59 Poliwag
# 60 Poliwhirl
# 61 Poliwrath
# 62 Abra
# 63 Kadabra
# 64 Alakazam
# 65 Machop
# 66 Machoke
# 67 Machamp
# 68 Bellsprout
# 69 Weepinbell
# 70 Victreebel
# 71 Tentacool
# 72 Tentacruel
# 73 Geodude
# ...

# %%
#to find a specific data
df.loc[df['type1'] == 'Fire']
# Out:
# Empty DataFrame
# Columns: [abilities, against_bug, against_dark, against_dragon, against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, name, percentage_male, pokedex_number, sp_attack, sp_defense, speed, type1, type2, weight_kg, generation, is_legendary]
# Index: []

# %%
df.describe()
# Out:
#        against_bug  against_dark  ...  generation  is_legendary
# count   801.000000    801.000000  ...  801.000000    801.000000
# mean      0.996255      1.057116  ...    3.690387      0.087391
# std       0.597248      0.438142  ...    1.930420      0.282583
# min       0.250000      0.250000  ...    1.000000      0.000000
# 25%       0.500000      1.000000  ...    2.000000      0.000000
# 50%       1.000000      1.000000  ...    4.000000      0.000000
# 75%       1.000000      1.000000  ...    5.000000      0.000000
# max       4.000000      4.000000  ...    7.000000      1.000000
#
# [8 rows x 34 columns]

# %%
#sorting
df.sort_values(['name'])
# Out:
#                                          abilities  ...  is_legendary
# 459                 ['Snow Warning', 'Soundproof']  ...             0
# 62   ['Synchronize', 'Inner Focus', 'Magic Guard']  ...             0
# 358        ['Pressure', 'Super Luck', 'Justified']  ...             0
# 616       ['Hydration', 'Sticky Hold', 'Unburden']  ...             0
# 680                              ['Stance Change']  ...             0
# ..                                             ...  ...           ...
# 570                                   ['Illusion']  ...             0
# 569                                   ['Illusion']  ...             0
# 40                  ['Inner Focus', 'Infiltrator']  ...             0
# 633                                     ['Hustle']  ...             0
# 717              ['Aura Break', 'Power Construct']  ...             1
#
# [801 rows x 41 columns]

# %%
df.sort_values(['name'],ascending=False)
# Out:
#                                          abilities  ...  is_legendary
# 717              ['Aura Break', 'Power Construct']  ...             1
# 633                                     ['Hustle']  ...             0
# 40                  ['Inner Focus', 'Infiltrator']  ...             0
# 569                                   ['Illusion']  ...             0
# 570                                   ['Illusion']  ...             0
# ..                                             ...  ...           ...
# 680                              ['Stance Change']  ...             0
# 616       ['Hydration', 'Sticky Hold', 'Unburden']  ...             0
# 358        ['Pressure', 'Super Luck', 'Justified']  ...             0
# 62   ['Synchronize', 'Inner Focus', 'Magic Guard']  ...             0
# 459                 ['Snow Warning', 'Soundproof']  ...             0
#
# [801 rows x 41 columns]

# %%
#name in ascending and type1 in descending
df.sort_values(['name','type1'], ascending=[1,0])
# Out:
#                                          abilities  ...  is_legendary
# 459                 ['Snow Warning', 'Soundproof']  ...             0
# 62   ['Synchronize', 'Inner Focus', 'Magic Guard']  ...             0
# 358        ['Pressure', 'Super Luck', 'Justified']  ...             0
# 616       ['Hydration', 'Sticky Hold', 'Unburden']  ...             0
# 680                              ['Stance Change']  ...             0
# ..                                             ...  ...           ...
# 570                                   ['Illusion']  ...             0
# 569                                   ['Illusion']  ...             0
# 40                  ['Inner Focus', 'Infiltrator']  ...             0
# 633                                     ['Hustle']  ...             0
# 717              ['Aura Break', 'Power Construct']  ...             1
#
# [801 rows x 41 columns]

# %%
# to add new column
df['total']=df['hp']+df['attack']

# %%
df.head(5)
# Out:
#                      abilities  against_bug  ...  is_legendary  total
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...             0     94
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...             0    122
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...             0    180
# 3     ['Blaze', 'Solar Power']          0.5  ...             0     91
# 4     ['Blaze', 'Solar Power']          0.5  ...             0    122
#
# [5 rows x 42 columns]

# %%
#to drop a column
df = df.drop(columns=['total'])
df.head(3)
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
#
# [3 rows x 41 columns]

# %%
df['total'] = df.iloc[:, 4:10].sum(axis=1) # axis 0 adds vertically 1 adds horizontally

# %%
# to rearrange columns... As a result the last tolal column will be 5th col (index 4)
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:41]]

# %%
df.head(3)
# Out:
#                      abilities  against_bug  ...  against_ground  against_ground
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...             1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...             1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...             1.0             1.0
#
# [3 rows x 18 columns]

# %%
# to save... Index = False will not save the index number in result csv
df.to_csv('modified.csv', index=False)

# %% [markdown]
# Filtering Data

# %%
ndf = pd.read_csv('/content/pokemon.csv')

# %%
ndf.shape
# Out:
# (801, 41)

# %%
print(ndf['type1'])
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
ndf.loc[(ndf['type1'] == 'grass') & (ndf['type2'] == 'poison')]
# Out:
#                                           abilities  ...  is_legendary
# 0                       ['Overgrow', 'Chlorophyll']  ...             0
# 1                       ['Overgrow', 'Chlorophyll']  ...             0
# 2                       ['Overgrow', 'Chlorophyll']  ...             0
# 42                      ['Chlorophyll', 'Run Away']  ...             0
# 43                        ['Chlorophyll', 'Stench']  ...             0
# 44                  ['Chlorophyll', 'Effect Spore']  ...             0
# 68                      ['Chlorophyll', 'Gluttony']  ...             0
# 69                      ['Chlorophyll', 'Gluttony']  ...             0
# 70                      ['Chlorophyll', 'Gluttony']  ...             0
# 314  ['Natural Cure', 'Poison Point', 'Leaf Guard']  ...             0
# 405  ['Natural Cure', 'Poison Point', 'Leaf Guard']  ...             0
# 406  ['Natural Cure', 'Poison Point', 'Technician']  ...             0
# ...

# %%
ndf.loc[ndf['name'].str.contains('mega')]
# Out:
#                                    abilities  ...  is_legendary
# 468  ['Speed Boost', 'Tinted Lens', 'Frisk']  ...             0
#
# [1 rows x 41 columns]

# %% [markdown]
# to drop rows of 'mega' and ~ at first

# %%
# Regular expression

import re

ndf.loc[ndf['type1'].str.contains('fire|grass', flags=re.I, regex=True)] # flag - ingnore case
# Out:
#                                            abilities  ...  is_legendary
# 0                        ['Overgrow', 'Chlorophyll']  ...             0
# 1                        ['Overgrow', 'Chlorophyll']  ...             0
# 2                        ['Overgrow', 'Chlorophyll']  ...             0
# 3                           ['Blaze', 'Solar Power']  ...             0
# 4                           ['Blaze', 'Solar Power']  ...             0
# ..                                               ...  ...           ...
# 761        ['Leaf Guard', 'Oblivious', 'Sweet Veil']  ...             0
# 762  ['Leaf Guard', 'Queenly Majesty', 'Sweet Veil']  ...             0
# 775                                  ['Shell Armor']  ...             0
# 786                    ['Grassy Surge', 'Telepathy']  ...             1
# 797                                  ['Beast Boost']  ...             1
#
# [130 rows x 41 columns]

# %%
ndf.loc[ndf['name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)] # returns pokemon starts with 'pi'
# Out:
#                                      abilities  ...  is_legendary
# 15   ['Keen Eye', 'Tangled Feet', 'Big Pecks']  ...             0
# 16   ['Keen Eye', 'Tangled Feet', 'Big Pecks']  ...             0
# 17   ['Keen Eye', 'Tangled Feet', 'Big Pecks']  ...             0
# 24                  ['Static', 'Lightningrod']  ...             0
# 126  ['Hyper Cutter', 'Mold Breaker', 'Moxie']  ...             0
# 171                 ['Static', 'Lightningrod']  ...             0
# 203                     ['Sturdy', 'Overcoat']  ...             0
# 220   ['Oblivious', 'Snow Cloak', 'Thick Fat']  ...             0
# 392                     ['Torrent', 'Defiant']  ...             0
# 498                     ['Blaze', 'Thick Fat']  ...             0
# 518     ['Big Pecks', 'Super Luck', 'Rivalry']  ...             0
# 730       ['Keen Eye', 'Skill Link', 'Pickup']  ...             0
#
# [12 rows x 41 columns]

# %%
df.loc[df['total']>5,['generation','is_legendary']]=['test1','test2']

# %%
ndf.groupby(['type1']).mean()
# Out:
#           against_bug  against_dark  ...  generation  is_legendary
# type1                                ...
# bug          0.826389      0.979167  ...    3.763889      0.041667
# dark         1.724138      0.534483  ...    4.275862      0.103448
# dragon       0.944444      1.037037  ...    4.296296      0.259259
# electric     0.871795      1.000000  ...    3.461538      0.128205
# fairy        0.472222      0.500000  ...    4.277778      0.055556
# fighting     0.535714      0.526786  ...    3.750000      0.000000
# fire         0.456731      0.951923  ...    3.634615      0.096154
# flying       0.500000      1.000000  ...    5.666667      0.333333
# ghost        0.527778      1.925926  ...    4.370370      0.037037
# grass        1.717949      0.967949  ...    3.935897      0.051282
# ground       1.062500      1.078125  ...    3.343750      0.062500
# ice          1.021739      1.130435  ...    3.565217      0.086957
# ...

# %%
ndf.groupby(['type1']).mean().sort_values('hp', ascending = False)
# Out:
#           against_bug  against_dark  ...  generation  is_legendary
# type1                                ...
# dragon       0.944444      1.037037  ...    4.296296      0.259259
# normal       0.895238      1.000000  ...    3.495238      0.028571
# fairy        0.472222      0.500000  ...    4.277778      0.055556
# ground       1.062500      1.078125  ...    3.343750      0.062500
# psychic      1.716981      1.943396  ...    3.849057      0.320755
# dark         1.724138      0.534483  ...    4.275862      0.103448
# ice          1.021739      1.130435  ...    3.565217      0.086957
# fighting     0.535714      0.526786  ...    3.750000      0.000000
# water        1.021930      1.017544  ...    3.210526      0.052632
# fire         0.456731      0.951923  ...    3.634615      0.096154
# flying       0.500000      1.000000  ...    5.666667      0.333333
# steel        0.531250      1.291667  ...    4.208333      0.250000
# ...

# %%
ndf.groupby(['type1']).sum()
# Out:
#           against_bug  against_dark  ...  generation  is_legendary
# type1                                ...
# bug             59.50         70.50  ...         271             3
# dark            50.00         15.50  ...         124             3
# dragon          25.50         28.00  ...         116             7
# electric        34.00         39.00  ...         135             5
# fairy            8.50          9.00  ...          77             1
# fighting        15.00         14.75  ...         105             0
# fire            23.75         49.50  ...         189             5
# flying           1.50          3.00  ...          17             1
# ghost           14.25         52.00  ...         118             1
# grass          134.00         75.50  ...         307             4
# ground          34.00         34.50  ...         107             2
# ice             23.50         26.00  ...          82             2
# ...

# %%
ndf.groupby(['type1']).count()
# Out:
#           abilities  against_bug  ...  generation  is_legendary
# type1                             ...
# bug              72           72  ...          72            72
# dark             29           29  ...          29            29
# dragon           27           27  ...          27            27
# electric         39           39  ...          39            39
# fairy            18           18  ...          18            18
# fighting         28           28  ...          28            28
# fire             52           52  ...          52            52
# flying            3            3  ...           3             3
# ghost            27           27  ...          27            27
# grass            78           78  ...          78            78
# ground           32           32  ...          32            32
# ice              23           23  ...          23            23
# normal          105          105  ...         105           105
# ...

# %%
ndf['count'] = 1
ndf.groupby(['type1']).count()['count']
# Out:
# type1
# bug          72
# dark         29
# dragon       27
# electric     39
# fairy        18
# fighting     28
# fire         52
# flying        3
# ghost        27
# grass        78
# ground       32
# ice          23
# normal      105
# poison       32
# psychic      53
# rock         45
# steel        24
# water       114
# Name: count, dtype: int64

# %%
ndf.groupby(['type1','type2']).count()['count']
# Out:
# type1  type2
# bug    electric     4
#        fairy        2
#        fighting     3
#        fire         2
#        flying      13
#                    ..
# water  ice          3
#        poison       3
#        psychic      5
#        rock         4
#        steel        1
# Name: count, Length: 148, dtype: int64

# %%
for df in pd.read_csv('pokemon.csv',chunksize=5):
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
# 4     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [5 rows x 41 columns]
# CHUNK DF
#                      abilities  against_bug  ...  generation  is_legendary
# 5     ['Blaze', 'Solar Power']         0.25  ...           1             0
# 6     ['Torrent', 'Rain Dish']         1.00  ...           1             0
# 7     ['Torrent', 'Rain Dish']         1.00  ...           1             0
# 8     ['Torrent', 'Rain Dish']         1.00  ...           1             0
# 9  ['Shield Dust', 'Run Away']         1.00  ...           1             0
#
# [5 rows x 41 columns]
# ...

# %%
new_df=pd.DataFrame(columns=df.columns)

for df in pd.read_csv('pokemon.csv',chunksize=5):
    results = df.groupby(['type1']).count()

    new_df = pd.concat([new_df,results])
